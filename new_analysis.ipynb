# %%
import matplotlib.pyplot as plt
import os

from fitting_tool import FittingTool

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.facecolor']='white'

# %% [markdown]
# <br>

# %% [markdown]
# Fit angular dependence with one line of code, by specifying the path to the folder with data.

# %%
fitting = FittingTool.get_ang_dep('ang_dep_example/')
# Out:
# Fitting voltage data
# .........................................................................
# Fitting absorption data
# ...................
# Runtime error in file:  Py_Au_4GHz_95deg_29dBm.txt
# .....................................................

# %% [markdown]
# <br>

# %% [markdown]
# Fit and plot data from a list of files

# %%
files = os.listdir('ang_dep_example/')

# %%
one_fit = FittingTool('ang_dep_example/', files[5:8])

# %%
one_fit.fit_data()
# Out:
# Fitting voltage data
# ...
# Fitting absorption data
# ...

# %%
one_fit.plot_data()
